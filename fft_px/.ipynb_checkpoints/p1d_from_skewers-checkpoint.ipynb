#   0.2443438   0.24398902  0.2401467   0.17485975 -0.08141442  0.23018793
#   0.23964894  0.17024681  0.20500553  0.24303447  0.24585312  0.24665547
#   0.24682822  0.24697035  0.24707786  0.21834061  0.0790809   0.09103171
#  -0.21757779 -0.68495687 -0.84690691 -0.87245512 -0.00247376  0.23750522
#   0.1026698   0.0895259  -0.39096632 -0.88092382 -0.02641159  0.20742933
#  -0.17249571 -0.82187519  0.21556953  0.22068612  0.21266074  0.2347718
#   0.18742165 -0.2091149  -0.00722146  0.24120323  0.2350538   0.25016726
#   0.2516878   0.25066325  0.22202005  0.23509352  0.25197496  0.25183213
#   0.2516845   0.25281109  0.25007961  0.22787884  0.20754683]

# %% [markdown]
# Choose redshift bin in which you want to measure the power spectrum

# %%
z_bin = 2.5
dz = 0.2
z_start = z_bin - dz/2
z_end = z_bin + dz/2
lam_lya = 1215.6 #Angstrom  
lamobs_start = lam_lya*(1+z_start)
lamobs_end = lam_lya*(1+z_end)
print(lamobs_start,lamobs_end)
pw_A  = 0.8
lamarray = np.arange(lamobs_start,lamobs_end,pw_A)
# Out:
# 4133.04 4376.16

# %% [markdown]
# For each skewer, extract the deltas in the redshift range of measurement

# %%
extracted_deltas = []
extracted_lamobs = []
for i in range(int(num_of_skewers)):
    ihdu=i+1
    z_qso=file[ihdu].header['Z']
    lam_obs = 10.0**(file[ihdu].data['LOGLAM'])
    delta_data=file[ihdu].data['DELTA']
    if np.any(lam_obs <= lamobs_start) and np.any(lam_obs >= lamobs_end):
        # Extract only the valid range
        filtered_deltas = delta_data[(lam_obs >= lamobs_start) & (lam_obs <= lamobs_end)]
        extracted_deltas.append(filtered_deltas)
        filtered_lamobs = lam_obs[(lam_obs >= lamobs_start) & (lam_obs <= lamobs_end)]
        extracted_lamobs.append(filtered_lamobs)
        #print(filtered_lamobs)
        #print(ihdu)
        #plt.plot(lam_obs,delta_data)
        #plt.plot(filtered_lamobs,filtered_deltas)
extracted_deltas = np.array(extracted_deltas)   
extracted_lamobs = np.array(extracted_lamobs) 
print(np.shape(extracted_deltas))
print('number of sightlines in the given redshift bin:',len(extracted_deltas[:,0]))
N_skewers = len(extracted_deltas[:,0])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 6
#       4 ihdu=i+1
#       5 z_qso=file[ihdu].header['Z']
# ----> 6 lam_obs = 10.0**(file[ihdu].data['LOGLAM'])
#       7 delta_data=file[ihdu].data['DELTA']
#       8 if np.any(lam_obs <= lamobs_start) and np.any(lam_obs >= lamobs_end):
#       9     # Extract only the valid range
#
# File /global/common/software/nersc/pe/conda-envs/24.1.0/python-3.11/nersc-python/lib/python3.11/site-packages/astropy/utils/decorators.py:837, in lazyproperty.__get__(self, obj, owner)
#     835         val = obj_dict.get(self._key, _NotFound)
#     836         if val is _NotFound:
# --> 837             val = self.fget(obj)
#     838             obj_dict[self._key] = val
#     839 return val
#
# File /global/common/software/nersc/pe/conda-envs/24.1.0/python-3.11/nersc-python/lib/python3.11/site-packages/astropy/io/fits/hdu/table.py:407, in _TableBaseHDU.data(self)
#     405 @lazyproperty
#     406 def data(self):
# --> 407     data = self._get_tbdata()
#     408     data._coldefs = self.columns
#     409     data._character_as_bytes = self._character_as_bytes
#
# File /global/common/software/nersc/pe/conda-envs/24.1.0/python-3.11/nersc-python/lib/python3.11/site-packages/astropy/io/fits/hdu/table.py:193, in _TableLikeHDU._get_tbdata(self)
#     191     data = raw_data[:tbsize].view(dtype=columns.dtype, type=np.rec.recarray)
#     192 else:
# --> 193     raw_data = self._get_raw_data(self._nrows, columns.dtype, self._data_offset)
#     194     if raw_data is None:
#     195         # This can happen when a brand new table HDU is being created
#     196         # and no data has been assigned to the columns, which case just
#     197         # return an empty array
#     198         raw_data = np.array([], dtype=columns.dtype)
#
# File /global/common/software/nersc/pe/conda-envs/24.1.0/python-3.11/nersc-python/lib/python3.11/site-packages/astropy/io/fits/hdu/base.py:552, in _BaseHDU._get_raw_data(self, shape, code, offset)
#     550     return np.ndarray(shape, dtype=code, buffer=self._buffer, offset=offset)
#     551 elif self._file:
# --> 552     return self._file.readarray(offset=offset, dtype=code, shape=shape)
#     553 else:
#     554     return None
#
# File /global/common/software/nersc/pe/conda-envs/24.1.0/python-3.11/nersc-python/lib/python3.11/site-packages/astropy/io/fits/file.py:409, in _File.readarray(self, size, offset, dtype, shape)
#     402 finally:
#     403     # Make sure we leave the file in the position we found it; on
#     404     # some platforms (e.g. Windows) mmaping a file handle can also
#     405     # reset its file pointer.
#     406     # Also for Windows when using mmap seek() may return weird
#     407     # negative values, which is fixed by calling tell() before.
#     408     self._file.tell()
# --> 409     self._file.seek(filepos)
#
# File /global/common/software/nersc/pe/conda-envs/24.1.0/python-3.11/nersc-python/lib/python3.11/gzip.py:393, in GzipFile.seek(self, offset, whence)
#     391 elif self.mode == READ:
#     392     self._check_not_closed()
# --> 393     return self._buffer.seek(offset, whence)
#     395 return self.offset
#
# File /global/common/software/nersc/pe/conda-envs/24.1.0/python-3.11/nersc-python/lib/python3.11/_compression.py:153, in DecompressReader.seek(self, offset, whence)
#     151 # Read and discard data until we reach the desired position.
#     152 while offset > 0:
# --> 153     data = self.read(min(io.DEFAULT_BUFFER_SIZE, offset))
#     154     if not data:
#     155         break
#
# File /global/common/software/nersc/pe/conda-envs/24.1.0/python-3.11/nersc-python/lib/python3.11/gzip.py:521, in _GzipReader.read(self, size)
#     517     if buf == b"":
#     518         raise EOFError("Compressed file ended before the "
#     519                        "end-of-stream marker was reached")
# --> 521 self._add_read_data( uncompress )
#     522 self._pos += len(uncompress)
#     523 return uncompress
#
# File /global/common/software/nersc/pe/conda-envs/24.1.0/python-3.11/nersc-python/lib/python3.11/gzip.py:525, in _GzipReader._add_read_data(self, data)
#     522     self._pos += len(uncompress)
#     523     return uncompress
# --> 525 def _add_read_data(self, data):
#     526     self._crc = zlib.crc32(data, self._crc)
#     527     self._stream_size = self._stream_size + len(data)
#
# KeyboardInterrupt:

# %% [markdown]
# Fourier transform of deltas

# %%
N_FFT  = 512
k_arr = np.fft.fftfreq(N_FFT)*2*np.pi/pw_A
#print(k_arr[:N_FFT//2])
delta_ft = np.zeros((len(extracted_deltas[:,0]),len(extracted_deltas[0,:])))
pad_ft  = np.zeros((len(extracted_deltas[:,0]),N_FFT),dtype=np.complex64)
padded_deltas = np.pad(extracted_deltas, pad_width=((0, 0), (0, N_FFT - len(extracted_deltas[0,:]))), mode='constant')

for l in range(len(extracted_deltas[:,0])):
    pad_ft[l,:] = np.fft.fft(padded_deltas[l,:])

plt.plot(k_arr[:N_FFT//2],pad_ft.real[0,:N_FFT//2])
plt.plot(k_arr[:N_FFT//2],pad_ft.imag[0,:N_FFT//2])

# %% [markdown]
# Average power spectrum in the given redshift bin

# %%
p1d_km = pw_A/N_FFT*1/N_skewers*np.sum(np.abs(pad_ft)**2,axis=0) # Ignored the resolution function R_a(x)

# %%
plt.plot(k_arr[:N_FFT//2],p1d_km[:N_FFT//2])
plt.xlabel('k [1/A]')
plt.ylabel('P1D [A]')
plt.title('Average 1D PS at z=%0.2f'%z_bin)
# Out:
# Text(0.5, 1.0, 'Average 1D PS at z=2.50')
